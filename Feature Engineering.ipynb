# %%
# 1. What is a parameter?
"""A parameter is a configuration variable internal to the model, whose value is estimated from the data. In machine learning, weights 
and biases in neural networks are examples of parameters learned during training."""

# 2. What is correlation?
"""Correlation measures the statistical relationship between two variables. 
It indicates how strongly changes in one variable are associated with changes in another. Values range from -1 to +1."""

# What does negative correlation mean?
"""Negative correlation means that as one variable increases, the other decreases. 
For example, if study time increases and errors decrease, there's a negative correlation between study time and errors."""

# 3. Define Machine Learning. What are the main components in Machine Learning?
"""Machine Learning is a method where systems learn from data to make predictions or decisions. 
Main components include data, model, algorithm, training, evaluation, and prediction."""

# 4. How does loss value help in determining whether the model is good or not?
"""Loss value measures how well the model's predictions match actual outcomes. 
A lower loss indicates better performance, guiding model tuning to improve accuracy and generalization."""

# 5. What are continuous and categorical variables?
"""Continuous variables take numerical values within a range (e.g., age, height), 
while categorical variables represent categories or labels (e.g., gender, color) without inherent numerical meaning."""

# 6. How do we handle categorical variables in Machine Learning? What are the common techniques?
"""Categorical variables are handled using encoding methods like One-Hot Encoding and Label Encoding. 
These techniques convert categories into numerical formats that machine learning algorithms can process."""

# 7. What do you mean by training and testing a dataset?
"""Training a dataset means using it to teach the model, while testing evaluates the model’s performance on 
unseen data to ensure it generalizes well beyond training data."""

# 8. What is sklearn.preprocessing?
"""`sklearn.preprocessing` is a module in scikit-learn that provides functions for scaling, encoding, 
and transforming input data to prepare it for machine learning models."""

# 9. What is a Test set?
"""A test set is a portion of the dataset used to evaluate the trained model’s performance. 
It ensures the model's predictions are accurate on unseen, real-world data."""

# 10. How do we split data for model fitting (training and testing) in Python?
"""In Python, we use `train_test_split()` from sklearn to divide data into training and testing sets. 
This helps assess model performance on new data."""

# How do you approach a Machine Learning problem?
"""Approach involves understanding the problem, collecting and preprocessing data, exploring data, 
selecting and training a model, evaluating its performance, and fine-tuning for better accuracy."""

# 11. Why do we have to perform EDA before fitting a model to the data?
"""EDA (Exploratory Data Analysis) helps understand data patterns, detect anomalies, and gain insights. 
It informs data preprocessing, feature selection, and improves model performance."""

# 12. What is correlation?
"""Correlation shows how two variables move in relation to each other. It helps identify dependencies and 
relationships important for feature selection and understanding data behavior."""

# 13. What does negative correlation mean?
"""Negative correlation means one variable increases as the other decreases. 
It indicates an inverse relationship between the two variables."""

# 14. How can you find correlation between variables in Python?
"""Use `pandas.corr()` function to calculate the correlation matrix between numerical variables. 
It shows pairwise correlation coefficients in the dataset."""

# 15. What is causation? Explain difference between correlation and causation with an example.
"""Causation implies that one event causes another. Correlation shows association without cause. 
For example, ice cream sales and drowning deaths correlate, but higher temperatures cause both—so no causation."""

# 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
"""An optimizer adjusts model parameters to minimize loss. Examples include SGD (simple gradient descent), 
Adam (adaptive momentum), and RMSProp. Adam combines speed and stability, making it widely used."""

# 17. What is sklearn.linear_model?
"""`sklearn.linear_model` provides linear models like LinearRegression, Ridge, and LogisticRegression. 
These models fit linear relationships between input features and target variables for prediction or classification."""

# 18. What does model.fit() do? What arguments must be given?
"""`model.fit()` trains the model using input (X) and target (y) data. 
It finds optimal parameters for prediction. Required arguments are training features and labels: `model.fit(X_train, y_train)```"""

# 19. What does model.predict() do? What arguments must be given?
"""`model.predict()` uses the trained model to make predictions on new data. 
It takes input features (X_test) as arguments and returns predicted output values."""

# 20. What are continuous and categorical variables?
"""Continuous variables are numeric and measurable, like age or weight. Categorical variables represent 
groups or categories like gender or city, and often need encoding for model training."""

# 21. What is feature scaling? How does it help in Machine Learning?
"""Feature scaling standardizes feature values to a common range, improving algorithm performance and convergence, 
especially in gradient-based models. Common techniques include normalization and standardization."""

# 22. How do we perform scaling in Python?
"""In Python, scaling is done using `StandardScaler` or `MinMaxScaler` from `sklearn.preprocessing`. 
Fit the scaler on training data and transform both training and test sets."""

# 23. What is sklearn.preprocessing?
"""`sklearn.preprocessing` provides utilities for transforming data, such as encoding, scaling, normalization, and imputation. 
It prepares raw data for machine learning models to perform effectively."""

# 24. How do we split data for model fitting (training and testing) in Python?
"""Use `train_test_split()` from `sklearn.model_selection` to divide data into training and testing subsets. 
It ensures the model is trained and validated on separate data."""

# 25. Explain data encoding?
"""Data encoding transforms categorical data into numerical format. Techniques include Label Encoding and One-Hot Encoding. 
This step is essential because machine learning models require numerical input."""
# Out:
# 'Data encoding transforms categorical data into numerical format. Techniques include Label Encoding and One-Hot Encoding. \nThis step is essential because machine learning models require numerical input.'
